# %%
E-Commerce Profitability Analysis

# %%
DATA PROCESSING, CLEANING, AND MANIPULATION

# %%
DATA PROCESSING

# %%
# 1. Importing the dataset

# %%
import pandas as pd

orders = pd.read_csv(r"G:\My Drive\Data Analysis Projects\E-Commerce\Dataset\orders.csv")

print(orders.head())
# Out:
#      order_id customer_id  order_date      channel payment_method     region  \
# 0  ORD-000001      C-0617  2025-06-24   Mobile App      Gift Card  Northeast
# 1  ORD-000002      C-0720  2025-08-23      Website    Credit Card    Midwest
# 2  ORD-000003      C-0189  2025-07-20      Website    Credit Card  Southeast
# 3  ORD-000004      C-0058  2025-07-17   Mobile App     Debit Card  Southeast
# 4  ORD-000005      C-0580  2025-10-11  Marketplace    Credit Card  Northeast
#
#    items_ordered primary_category  gross_revenue  discount_pct  \
# 0              2      Electronics         261.39             0
# 1              1           Beauty          24.02             0
# 2              2             Toys          52.60             0
# 3              2           Sports          30.63             5
# 4              1           Sports          11.99            25
#
#    discount_amount  shipping_cost  product_cost  platform_fee  \
# 0             0.00          22.28         92.30          0.00
# 1             0.00           3.98         10.75          0.00
# 2             0.00          14.60         31.41          0.00
# 3             1.53          30.98         16.27          0.00
# 4             3.00          10.30          6.88          1.35
#
#    transaction_fee returned  refund_amount  net_revenue  total_costs  profit
# 0             7.88       No            0.0       261.39       122.46  138.93
# 1             1.00       No            0.0        24.02        15.73    8.29
# 2             1.83       No            0.0        52.60        47.84    4.76
# 3             1.14       No            0.0        29.10        48.39  -19.29
# 4             0.56       No            0.0         8.99        19.09  -10.10

# %%
# 2. Checking and addressing missing and NaN values

# %%
# a. Checking for missing values
orders.isna().sum()
# Out:
# order_id            0
# customer_id         0
# order_date          0
# channel             0
# payment_method      0
# region              0
# items_ordered       0
# primary_category    0
# gross_revenue       0
# discount_pct        0
# discount_amount     0
# shipping_cost       0
# product_cost        0
# platform_fee        0
# transaction_fee     0
# returned            0
# refund_amount       0
# net_revenue         0
# total_costs         0
# profit              0
# dtype: int64

# %%
# 3. Checking and converting data types:

# %%
#. Checking data types
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          2000 non-null   object
#  1   customer_id       2000 non-null   object
#  2   order_date        2000 non-null   object
#  3   channel           2000 non-null   object
#  4   payment_method    2000 non-null   object
#  5   region            2000 non-null   object
#  6   items_ordered     2000 non-null   int64
#  7   primary_category  2000 non-null   object
#  8   gross_revenue     2000 non-null   float64
#  9   discount_pct      2000 non-null   int64
#  10  discount_amount   2000 non-null   float64
#  11  shipping_cost     2000 non-null   float64
#  12  product_cost      2000 non-null   float64
#  13  platform_fee      2000 non-null   float64
#  14  transaction_fee   2000 non-null   float64
#  15  returned          2000 non-null   object
#  16  refund_amount     2000 non-null   float64
#  17  net_revenue       2000 non-null   float64
#  18  total_costs       2000 non-null   float64
#  19  profit            2000 non-null   float64
# dtypes: float64(10), int64(2), object(8)
# memory usage: 312.6+ KB

# %%
# a. Converting Date columns
date_cols = ['order_date']
for col in date_cols:
    orders[col] = pd.to_datetime(orders[col], format='%Y-%m-%d')

# %%
# b. Converting to Categorical to save memory and improve speed
cat_cols = [ 'customer_id', 'channel', 'payment_method', 'region', 'primary_category']
for col in cat_cols:
    orders[col] = orders[col].astype('category')

# %%
# c. Converting the return column to Boolean type
orders['returned'] = orders['returned'].astype('bool')

# %%
# d. Downcasting integer Columns to memory-efficient types
# Specific smaller-range integers
int_cols = ['items_ordered', 'discount_pct']
orders[int_cols] = orders[int_cols].astype('int8')

# %%
# e. Downcasting operational financial columns to float32
float_cols = ['gross_revenue', 'discount_amount', 'shipping_cost', 
              'product_cost', 'platform_fee', 'transaction_fee', 'refund_amount'
             ]

for col in float_cols:
    orders[col] = orders[col].astype('float32')

# %%
# e. Ensuring target financial metrics are float64 for aggregation precision
float64_cols = ['net_revenue', 'total_costs', 'profit']
for col in float64_cols:
    orders[col] = orders[col].astype('float64')

print(orders.dtypes)
# Out:
# order_id                    object
# customer_id               category
# order_date          datetime64[ns]
# channel                   category
# payment_method            category
# region                    category
# items_ordered                 int8
# primary_category          category
# gross_revenue              float32
# discount_pct                  int8
# discount_amount            float32
# shipping_cost              float32
# product_cost               float32
# platform_fee               float32
# transaction_fee            float32
# returned                      bool
# refund_amount              float32
# net_revenue                float64
# total_costs                float64
# profit                     float64
# dtype: object

# %%
# 4. Checking for duplicates

# %%
duplicate_rows = orders.duplicated()
print(f"Number of duplicate rows: {duplicate_rows.sum()}")

duplicates = orders[orders.duplicated()]
print(duplicates)
# Out:
# Number of duplicate rows: 0
# Empty DataFrame
# Columns: [order_id, customer_id, order_date, channel, payment_method, region, items_ordered, primary_category, gross_revenue, discount_pct, discount_amount, shipping_cost, product_cost, platform_fee, transaction_fee, returned, refund_amount, net_revenue, total_costs, profit]
# Index: []

# %%
# 5. Data transformation (trimming)

# %%
import re

# Identify object columns
obj_cols = orders.select_dtypes(include=['object']).columns

for col in obj_cols:
# Trimming Whitespaces
    orders[col] = orders[col].str.strip()

# %%
# 6. Resetting the table's index column

# %%
orders = orders.reset_index(drop=True)

print(orders.head())
print("Cleaning Process Complete!")
print(f"Total Rows: {len(orders)}")
print(f"Null Values Remaining: {orders.isnull().sum().sum()}")
# Out:
#      order_id customer_id order_date      channel payment_method     region  \
# 0  ORD-000001      C-0617 2025-06-24   Mobile App      Gift Card  Northeast
# 1  ORD-000002      C-0720 2025-08-23      Website    Credit Card    Midwest
# 2  ORD-000003      C-0189 2025-07-20      Website    Credit Card  Southeast
# 3  ORD-000004      C-0058 2025-07-17   Mobile App     Debit Card  Southeast
# 4  ORD-000005      C-0580 2025-10-11  Marketplace    Credit Card  Northeast
#
#    items_ordered primary_category  gross_revenue  discount_pct  \
# 0              2      Electronics     261.390015             0
# 1              1           Beauty      24.020000             0
# 2              2             Toys      52.599998             0
# 3              2           Sports      30.629999             5
# 4              1           Sports      11.990000            25
#
#    discount_amount  shipping_cost  product_cost  platform_fee  \
# 0             0.00      22.280001     92.300003          0.00
# 1             0.00       3.980000     10.750000          0.00
# 2             0.00      14.600000     31.410000          0.00
# 3             1.53      30.980000     16.270000          0.00
# 4             3.00      10.300000      6.880000          1.35
#
#    transaction_fee  returned  refund_amount  net_revenue  total_costs  profit
# 0             7.88      True            0.0       261.39       122.46  138.93
# 1             1.00      True            0.0        24.02        15.73    8.29
# 2             1.83      True            0.0        52.60        47.84    4.76
# 3             1.14      True            0.0        29.10        48.39  -19.29
# 4             0.56      True            0.0         8.99        19.09  -10.10
# Cleaning Process Complete!
# Total Rows: 2000
# Null Values Remaining: 0

# %%
# CREATING AND SAVING A CLEAN CSV FILE

# %%
orders.to_csv(r"G:\My Drive\Data Analysis Projects\E-Commerce\Cleaned\orders.csv", index=False)

import os
file_path = r"G:\My Drive\Data Analysis Projects\E-Commerce\Cleaned\orders.csv"
if os.path.exists(file_path):
    print("File successfully created!")
# Out:
# File successfully created!

# %% [markdown]
# CREATING AND SAVING DATABASE

# %%
import pandas as pd
import sqlite3


# 1. Establishing a connection
# This creates the file 'orders.db' in the working directory
with sqlite3.connect('orders.db') as conn:

# 2. Writing the data to a table
# 'name' is the table name for the db
# 'if_exists' replaces the table if it already exists
    orders.to_sql(name='orders', con=conn, if_exists='replace', index=False)

# 3. To make sure the database is correctly built before downloading it
import os
file_stats = os.stat('orders.db')
print(f"Database size: {file_stats.st_size / (1024 * 1024):.2f} MB")
# Out:
# Database size: 0.33 MB
